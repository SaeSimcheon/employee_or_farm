# %%
# %%timeit
import sys
sys.stdin = open("in1.txt", "rt")
card = list(range(1,21))
for i in range(10):
    a, b = map(int, sys.stdin.readline().split())
    card2 = card[a-1:b]
    card2 = card2[::-1]
    card[a-1:b] = card2
for j in card:
    print(j,end=' ')
# Out:
# 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6 14 15 16 17 18 19 20 1 2 3 4 10 9 8 7 13 12 11 5 6
# ...

# %% [markdown]
# 첫 시도 100
